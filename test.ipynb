# %%
import requests
import urllib.parse
from bs4 import BeautifulSoup

SEARX_URL   = "http://localhost:8124/search"
NUM_PAGES   = 100
QUERY       = "Singapore"

def normalize_pretty_url(pretty_url: str) -> str:
    url = pretty_url.replace(' › ', '/').replace('›', '/')
    return url



resp = requests.get(SEARX_URL, params=params)
# results = resp.json().get("results")

resp


## write script to enable search engines as well as images for bing, yahoo, etc
# Out:
# <Response [200]>

# %%
import requests

SEARX_URL   = "http://localhost:8124/search"
NUM_PAGES   = 100
QUERY       = "Singapore"

for i in range(1, 3):
    print("="*40 + "NEW PAGE" + "="*40)
    params = {
        "q": "singapore",
        "format":   "json",
        "language": "en",
        "categories":"general",
        "pageno": 1,
        "time_range": "year"
    }
    
    resp = requests.get(SEARX_URL, params=params)
    results = resp.json().get("results")

    extracted = []

    for hit in results:
        print("\n")
        print(hit)
        print("unnormalised base", hit.get("url"))
        print("Title: ", hit.get("title"))
        print("Snippet:", hit.get("content"))
# Out:
# ========================================NEW PAGE========================================
#
#
# {'url': 'https://en.wikipedia.org/wiki/Singapore', 'title': 'Singapore', 'content': "6 May 2025 — Singapore is an island country and city-state in Southeast Asia. The country's territory comprises one main island, 63 satellite islands and islets, and one ...", 'thumbnail': 'data:image/png;base64,...', 'engine': 'google', 'template': 'default.html', 'parsed_url': ['https', 'en.wikipedia.org', '/wiki/Singapore', '', '', ''], 'img_src': '', 'priority': '', 'engines': ['google'], 'positions': [1], 'score': 1.0, 'category': 'general'}
# unnormalised base https://en.wikipedia.org/wiki/Singapore
# Title:  Singapore
# Snippet: 6 May 2025 — Singapore is an island country and city-state in Southeast Asia. The country's territory comprises one main island, 63 satellite islands and islets, and one ...
#
#
# ...

# %%
# import requests

# SEARX_URL = "http://localhost:8080/search"
# NUM_PAGES = 10
# QUERY     = "Singapore"

# def normalize_pretty_url(pretty_url: str) -> str:
#     return pretty_url.replace(' › ', '/').replace('›', '/')

# def fetch_page(page_no: int):
#     params = {
#         "q": QUERY,
#         "format":   "json",
#         "language": "en",
#         "locale":   "en_US",
#         "categories": "general",
#         "engines": ["google,reddit,bing"],
#         "pageno": page_no
#     }
#     resp = requests.get(SEARX_URL, params=params)
#     resp.raise_for_status()
#     return resp.json().get("results", [])

# def main():
#     all_urls = []
    
#     for p in range(1, NUM_PAGES + 1):
#         print(f"\n--- Fetching page {p} ---")
#         results = fetch_page(p)
#         if not results:
#             print(" no results on this page.")
#             continue
        
#         for hit in results:
#             pretty = hit.get("pretty_url", "")
#             url    = normalize_pretty_url(pretty)
#             title  = hit.get("title", "").strip()
#             snippet = hit.get("content", "").strip()
            
#             print(f"URL:     {url}")
#             print(f"Title:   {title}")
#             print(f"Snippet: {snippet}\n")
            
#             all_urls.append(url)
    
#     unique_urls = set(all_urls)
#     print("="*40)
#     print(f"Total hits fetched:       {len(all_urls)}")
#     print(f"Total unique URLs found:  {len(unique_urls)}")

# if __name__ == "__main__":
#     main()
# Out:
# --- Fetching page 1 ---
# URL:     https://en.wikipedia.org/wiki/Singapore
# Title:   Singapore
# Snippet:
#
# URL:     https://www.gov.sg/
# Title:   Singapore
# Snippet:
#
# URL:     https://en.wikipedia.org/wiki/Singapore
# Title:   Singapore - Wikipedia
# Snippet: Singapore gained self-governance in 1959 and, in 1963, became part of the new federation of Malaysia, alongside Malaya, North Borneo, and Sarawak. Ideological differences led to …
#
# URL:     https://www.sicw.gov.sg/about-singapore
# Title:   About Singapore
# Snippet: About Singapore Singapore is a sunny, tropical island in Southeast Asia, off the southern tip of the Malay Peninsula. The city-state is 710 square kilometres and inhabited by five million people …
#
# URL:     https://www.britannica.com/place/Singapore
# Title:   Singapore | Facts, Geography, History, & Points of Interest
# ...
