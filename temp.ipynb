# %%
import os
import json
import time
import requests
from datetime import datetime
from app.configs.config import CrawlerConfig
from app.utils.logger import logger

class Crawler:
    """Searches SearXNG and stores unique links in a master JSONL and in a per‐run JSONL."""

    def __init__(self, crawler_config: CrawlerConfig):
        self.crawler_config = crawler_config
        self.searx_url     = crawler_config.searxng_url
        # master file for persistence
        self.master_path   = crawler_config.links_file_path

        # ensure master directory exists
        master_dir = os.path.dirname(self.master_path)
        if master_dir and not os.path.isdir(master_dir):
            os.makedirs(master_dir, exist_ok=True)

        # load seen URLs for dedupe
        self.seen_urls: set[str] = set()
        if os.path.exists(self.master_path):
            with open(self.master_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        entry = json.loads(line)
                        url = entry.get("href")
                        if url:
                            self.seen_urls.add(url)
                    except json.JSONDecodeError:
                        logger.warning("Skipping malformed JSON line in master file.")

    def _make_run_filename(self, prefix: str) -> str:
        ts = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
        base_dir = os.path.dirname(self.master_path) or "."
        run_name = f"{prefix}_links_{ts}.jsonl"
        return os.path.join(base_dir, run_name)

    ###################################
    ##        search helpers        ##
    ###################################
    def _make_searx_request(self, query: str, page: int = 1) -> list[dict]:
        if not query or not query.strip():
            logger.warning("Empty query supplied to SearXNG request.")
            return []

        # Ensure correct endpoint (some instances expect /search)
        url = self.searx_url
        if not url.rstrip("/").endswith("/search"):
            url = url.rstrip("/") + "/search"

        params = {
            "q": query,
            "format": "json",
            "language": self.crawler_config.language,
            "categories": "general",
            "pageno": page,
            "time_range": self.crawler_config.time_range,
        }

        logger.debug("SearXNG request: %s params: %s", url, params)
        try:
            resp = requests.get(url, params=params, timeout=self.crawler_config.timeout)
            resp.raise_for_status()
        except requests.RequestException as e:
            logger.error("SearX request failed (network/HTTP): %s", e)
            return []

        # Try to parse JSON
        try:
            data = resp.json()
        except ValueError:
            logger.error("Failed to decode JSON from SearXNG. Response text: %s", resp.text[:1000])
            return []

        # Sanity-check structure
        if "results" not in data:
            logger.warning("'results' key missing in SearXNG response. Full response: %s", data)
            return []

        results = data["results"]
        if not results:
            logger.info(
                "Empty results for query=%r page=%d. Response snippet: %s",
                query,
                page,
                json.dumps(data)[:1000],
            )
        return results

    def _make_searx_image_request(self, query: str, page: int = 1) -> list[dict]:
        """Single image-search request to SearXNG."""
        if not query or not query.strip():
            logger.warning("Empty query supplied to SearXNG image request.")
            return []

        url = self.searx_url.rstrip("/")
        if not url.endswith("/search"):
            url += "/search"

        params = {
            "q": query,
            "format": "json",
            "language": self.crawler_config.language,
            "categories": "images",          # <── images only
            "pageno": page,
            "time_range": self.crawler_config.time_range,
        }

        logger.debug("SearXNG image request: %s params: %s", url, params)
        try:
            resp = requests.get(url, params=params, timeout=self.crawler_config.timeout)
            resp.raise_for_status()
        except requests.RequestException as e:
            logger.error("SearX image request failed (network/HTTP): %s", e)
            return []

        try:
            data = resp.json()
        except ValueError:
            logger.error("Failed to decode JSON from SearXNG (images). Response text: %s",
                         resp.text[:1000])
            return []

        if "results" not in data:
            logger.warning("'results' key missing in SearXNG image response. Full response: %s", data)
            return []

        results = data["results"]
        if not results:
            logger.info("Empty image results for query=%r page=%d.", query, page)
        return results

    def search_and_store(self, query: str) -> str:
        logger.info("Searching for '%s'...", query)

        run_path = self._make_run_filename("run")
        added = skipped = 0

        # open both master (append) and run (write fresh)
        with open(self.master_path, "a", encoding="utf-8") as master_f, \
             open(run_path,        "w", encoding="utf-8") as run_f:

            for page in range(1, self.crawler_config.pages + 1):
                logger.info("Page %d/%d", page, self.crawler_config.pages)
                results = self._make_searx_request(query, page)
                if not results:
                    logger.warning("No results on page %d", page)
                    continue

                for hit in results:
                    url = hit.get("url")
                    if not url:
                        logger.warning("Skipping hit with no URL")
                        continue

                    if url in self.seen_urls:
                        skipped += 1
                        continue

                    record = {
                        "title":           hit.get("title", ""),
                        "href":            url,
                        "content":         hit.get("content", ""),
                        "stored_at":       datetime.utcnow().isoformat(),
                        "original_query":  query,
                        "page":            page,
                        "engine":          hit.get("engine", "unknown"),
                    }

                    line = json.dumps(record, ensure_ascii=False)
                    master_f.write(line + "\n")
                    master_f.flush()
                    os.fsync(master_f.fileno())

                    run_f.write(line + "\n")
                    run_f.flush()
                    os.fsync(run_f.fileno())

                    self.seen_urls.add(url)
                    added += 1

        logger.info("Done. %d new, %d skipped.", added, skipped)
        return run_path

    def search_and_store_batch(self, queries: list[str]) -> str:
        logger.info("Batch search for %d queries...", len(queries))

        run_path = self._make_run_filename("batch_run")
        total_added = total_skipped = 0

        with open(self.master_path, "a", encoding="utf-8") as master_f, \
             open(run_path,        "w", encoding="utf-8") as run_f:

            for i, query in enumerate(queries, start=1):
                logger.info("Query %d/%d: '%s'", i, len(queries), query)
                for page in range(1, self.crawler_config.pages + 1):
                    results = self._make_searx_request(query, page)
                    if not results:
                        logger.warning("No results on page %d for '%s'", page, query)
                        continue

                    for hit in results:
                        url = hit.get("url")
                        if not url:
                            logger.warning("Skipping hit with no URL")
                            continue

                        if url in self.seen_urls:
                            total_skipped += 1
                            continue

                        record = {
                            "title":           hit.get("title", ""),
                            "href":            url,
                            "content":         hit.get("content", ""),
                            "stored_at":       datetime.utcnow().isoformat(),
                            "original_query":  query,
                            "page":            page,
                            "engine":          hit.get("engine", "unknown"),
                        }

                        line = json.dumps(record, ensure_ascii=False)
                        master_f.write(line + "\n")
                        master_f.flush()
                        os.fsync(master_f.fileno())

                        run_f.write(line + "\n")
                        run_f.flush()
                        os.fsync(run_f.fileno())

                        self.seen_urls.add(url)
                        total_added += 1


        logger.info("Batch done. %d new, %d skipped.", total_added, total_skipped)
        return run_path

    def search_and_store_images(self, query: str) -> str:
        """Search for images only (single query)."""
        logger.info("Searching IMAGES for '%s'...", query)

        run_path = self._make_run_filename("run_images")
        added = skipped = 0

        with open(self.master_path, "a", encoding="utf-8") as master_f, \
             open(run_path, "w", encoding="utf-8") as run_f:

            for page in range(1, self.crawler_config.pages + 1):
                logger.info("Image page %d/%d", page, self.crawler_config.pages)
                results = self._make_searx_image_request(query, page)
                if not results:
                    logger.warning("No image results on page %d", page)
                    continue

                for hit in results:
                    url = hit.get("url")
                    if not url:
                        logger.warning("Skipping image hit with no URL")
                        continue

                    if url in self.seen_urls:
                        skipped += 1
                        continue

                    record = {
                        "title":          hit.get("title", ""),
                        "href":           url,
                        "content":        hit.get("content", ""),
                        "stored_at":      datetime.utcnow().isoformat(),
                        "original_query": query,
                        "page":           page,
                        "engine":         hit.get("engine", "unknown"),
                        "type":           "image",          # explicit flag
                        "img_src":        hit.get("img_src"),
                        "thumbnail_src":  hit.get("thumbnail_src"),
                    }

                    line = json.dumps(record, ensure_ascii=False)
                    master_f.write(line + "\n")
                    master_f.flush()
                    os.fsync(master_f.fileno())

                    run_f.write(line + "\n")
                    run_f.flush()
                    os.fsync(run_f.fileno())

                    self.seen_urls.add(url)
                    added += 1

        logger.info("Image search done. %d new, %d skipped.", added, skipped)
        return run_path
    
    def search_and_store_images_batch(self, queries: list[str]) -> str:
        """Batch image search for multiple queries."""
        logger.info("Batch image search for %d queries...", len(queries))

        run_path = self._make_run_filename("batch_images")
        total_added = total_skipped = 0

        with open(self.master_path, "a", encoding="utf-8") as master_f, \
             open(run_path, "w", encoding="utf-8") as run_f:

            for i, query in enumerate(queries, start=1):
                logger.info("Image query %d/%d: '%s'", i, len(queries), query)
                for page in range(1, self.crawler_config.pages + 1):
                    results = self._make_searx_image_request(query, page)
                    if not results:
                        logger.warning("No image results on page %d for '%s'", page, query)
                        continue

                    for hit in results:
                        url = hit.get("url")
                        if not url:
                            logger.warning("Skipping image hit with no URL")
                            continue

                        if url in self.seen_urls:
                            total_skipped += 1
                            continue

                        record = {
                            "title":          hit.get("title", ""),
                            "href":           url,
                            "content":        hit.get("content", ""),
                            "stored_at":      datetime.utcnow().isoformat(),
                            "original_query": query,
                            "page":           page,
                            "engine":         hit.get("engine", "unknown"),
                            "type":           "image",
                            "img_src":        hit.get("img_src"),
                            "thumbnail_src":  hit.get("thumbnail_src"),
                        }

                        line = json.dumps(record, ensure_ascii=False)
                        master_f.write(line + "\n")
                        master_f.flush()
                        os.fsync(master_f.fileno())

                        run_f.write(line + "\n")
                        run_f.flush()
                        os.fsync(run_f.fileno())

                        self.seen_urls.add(url)
                        total_added += 1

        logger.info("Batch image search done. %d new, %d skipped.", total_added, total_skipped)
        return run_path

# %%
config = CrawlerConfig()
crawler = Crawler(config)

crawler._make_searx_image_request("singapore")
# Out:
# [{'template': 'images.html',
#   'url': 'https://ar.inspiredpencil.com/pictures-2023/singapore-wallpaper-marina-bay-sands',
#   'thumbnail_src': 'https://ts3.mm.bing.net/th?id=OIP.PAo9a9nygMRcEn7eTM3x4gHaFU&pid=15.1',
#   'img_src': 'https://images.hdqwalls.com/wallpapers/singapore-skyscrapers-marina-bay-sands-evening-4k-es.jpg',
#   'content': '\ue000Singapore\ue001 Wallpaper Marina Bay Sands',
#   'title': 'Singapore Wallpaper Marina Bay Sands',
#   'source': 'ar.inspiredpencil.com',
#   'resolution': '4000×2870',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'ar.inspiredpencil.com',
#    '/pictures-2023/singapore-wallpaper-marina-bay-sands',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [5, 2],
#   'score': 1.4,
#   'category': 'images',
#   'filesize': '5.08 MB'},
#  {'template': 'images.html',
#   'url': 'https://ar.inspiredpencil.com/pictures-2023/singapore',
#   'thumbnail_src': 'https://ts3.mm.bing.net/th?id=OIP.vg1Wdff9MCVXFYs__FrwDwHaHa&pid=15.1',
#   'img_src': 'https://i.natgeofe.com/k/95d61645-a0c7-470f-b198-74a399dd5dfb/singapore-city_square.jpg',
#   'content': '\ue000Singapore\ue001',
#   'title': 'Singapore',
#   'source': 'ar.inspiredpencil.com',
#   'resolution': '3072×3072',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'ar.inspiredpencil.com',
#    '/pictures-2023/singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [1],
#   'score': 1.0,
#   'category': 'images'},
#  {'url': 'https://www.britannica.com/place/Singapore',
#   'title': 'Singapore | Facts, Geography, History, & Points of Interest ...',
#   'content': 'Singapore | Facts, Geography, History ...',
#   'source': 'Britannica (201KB)',
#   'resolution': '2000 x 1350',
#   'img_src': 'https://cdn.britannica.com/54/183754-050-3C534BA7/World-Data-Locator-Map-Singapore.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDEFIL_2YnzHf0nm1l8h-p6vPCM0vlW0rLNozCWxvHJlno3vI&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.britannica.com',
#    '/place/Singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [1],
#   'score': 1.0,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/187493411@N03/54481954010',
#   'img_src': '//live.staticflickr.com/65535/54481954010_b8fe58ee28_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54481954010_b8fe58ee28_n.jpg',
#   'source': 'Hadi Hormozi @ Flickr',
#   'resolution': '450 x 800',
#   'template': 'images.html',
#   'author': 'Hadi Hormozi',
#   'title': 'Singapore',
#   'content': 'Skyscraper, Singapore',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/187493411@N03/54481954010',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [1],
#   'score': 1.0,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.stokedtotravel.com/singapore-travel-guide/',
#   'title': 'Best Things to See and Do in Singapore - Stoked To Travel',
#   'content': '',
#   'img_src': 'https://www.stokedtotravel.com/wp-content/uploads/2020/11/Singapore-1.jpg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse2.mm.bing.net%2Fth%2Fid%2FOIP.8Tuqfv4sTaSGvOvdCGYJFwHaFQ%3Fr%3D0%26pid%3DApi&sp=1755935022T94470cca141e3534c1efb16089caf58af294b43e5c7d162ce9557db148b99769',
#   'resolution': '1747x1240',
#   'img_format': 'jpeg',
#   'filesize': '237.05 KB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'www.stokedtotravel.com',
#    '/singapore-travel-guide/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [1],
#   'score': 1.0,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://en.wikipedia.org/wiki/File:Singapore_Skyline.jpg',
#   'thumbnail_src': 'https://ts3.mm.bing.net/th?id=OIP.Qw7L6c8_KmVPkwIE_megDQHaE8&pid=15.1',
#   'img_src': 'http://upload.wikimedia.org/wikipedia/commons/0/01/Singapore_Skyline.jpg',
#   'content': 'File:\ue000Singapore\ue001 Skyline.jpg - Wikipedia, the free encyclopedia',
#   'title': 'File:Singapore Skyline.jpg - Wikipedia, the free encyclopedia',
#   'source': 'en.wikipedia.org',
#   'resolution': '4272×2848',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'en.wikipedia.org',
#    '/wiki/File:Singapore_Skyline.jpg',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [4, 5],
#   'score': 0.9,
#   'category': 'images',
#   'filesize': '5.34 MB'},
#  {'template': 'images.html',
#   'url': 'http://www.guideoftheworld.com/singapore-map.html',
#   'thumbnail_src': 'https://ts3.mm.bing.net/th?id=OIP.hL2_9VR22XVVSIPKP1sqOwHaFq&pid=15.1',
#   'img_src': 'http://www.guideoftheworld.com/wp-content/uploads/map/singapore_political_map.jpg',
#   'content': '\ue000Singapore\ue001 Map - Guide of the World',
#   'title': 'Singapore Map - Guide of the World',
#   'source': 'guideoftheworld.com',
#   'resolution': '3000×2294',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'www.guideoftheworld.com',
#    '/singapore-map.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [12, 4],
#   'score': 0.6666666666666666,
#   'category': 'images',
#   'filesize': '508.26 KB'},
#  {'template': 'images.html',
#   'url': 'https://www.mercoledituttalasettimana.com/singapore-in-tre-giorni/',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.BIEK938NwNUJAqolqmc4SgHaEK&pid=15.1',
#   'img_src': 'https://www.mercoledituttalasettimana.com/wp-content/uploads/2023/11/singapore-in-tre-giorni.webp',
#   'content': '\ue000Singapore\ue001 in tre giorni: itinerario e quartieri da vedere',
#   'title': 'Singapore in tre giorni: itinerario e quartieri da vedere',
#   'source': 'mercoledituttalasettimana.com',
#   'resolution': '2400×1350',
#   'img_format': 'unknown',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.mercoledituttalasettimana.com',
#    '/singapore-in-tre-giorni/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [7, 6],
#   'score': 0.6190476190476191,
#   'category': 'images',
#   'filesize': '524.80 KB'},
#  {'template': 'images.html',
#   'url': 'https://www.klm.co.th/travel-guide/destinations/asia/singapore/singapore',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.3AMBe2GzMDvyieknAtS5BAHaDt&pid=15.1',
#   'img_src': 'https://img.static-kl.com/images/media/E09ABA7F-D6D2-44EA-826E076B1F616512',
#   'content': 'Discover \ue000Singapore\ue001 with our Travel Guide - KLM Thailand',
#   'title': 'Discover Singapore with our Travel Guide - KLM Thailand',
#   'source': 'klm.co.th',
#   'resolution': '1280×640',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.klm.co.th',
#    '/travel-guide/destinations/asia/singapore/singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [2],
#   'score': 0.5,
#   'category': 'images'},
#  {'url': 'https://www.expedia.co.jp/en/Singapore.dx161',
#   'title': 'Visit Singapore: 2025 Travel Guide for Singapore, Asia | Expedia',
#   'content': 'Travel Guide for Singapore, Asia | Expedia',
#   'source': 'www.expedia.co.jp (319KB)',
#   'resolution': '2560 x 1440',
#   'img_src': 'https://a.travel-assets.com/findyours-php/viewfinder/images/res70/542000/542607-singapore.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQl4OKiQJ_bnuWcYmKbhZBit6hi7lojj3uJxQ7dnIskMGTyPqQ&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.expedia.co.jp',
#    '/en/Singapore.dx161',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [2],
#   'score': 0.5,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/187493411@N03/54241574261',
#   'img_src': '//live.staticflickr.com/65535/54241574261_ee2712c986_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54241574261_ee2712c986_n.jpg',
#   'source': 'Hadi Hormozi @ Flickr',
#   'resolution': '800 x 450',
#   'template': 'images.html',
#   'author': 'Hadi Hormozi',
#   'title': 'Singapore',
#   'content': 'Marina at Keppel Bay - Singapore',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/187493411@N03/54241574261',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [2],
#   'score': 0.5,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.expedia.co.uk/things-to-do/singapore-city-tour-with-guide.a1378878.activity-details',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.fKSK23E-__gZMHRG4u0zzAHaEq&pid=15.1',
#   'img_src': 'https://mediaim.expedia.com/localexpert/1378878/a052e968-fd05-40be-87f8-3b9c966c6da2.jpg',
#   'content': '\ue000Singapore\ue001 City Tour with Guide',
#   'title': 'Singapore City Tour with Guide',
#   'source': 'Expedia.co.uk',
#   'resolution': '1200×755',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.expedia.co.uk',
#    '/things-to-do/singapore-city-tour-with-guide.a1378878.activity-details',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [19, 8],
#   'score': 0.35526315789473684,
#   'category': 'images',
#   'filesize': '127.91 KB'},
#  {'template': 'images.html',
#   'url': 'https://www.britannica.com/place/Singapore',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.DJ55Cr1MyIFPCgKHmmuZCwHaDJ&pid=15.1',
#   'img_src': 'https://cdn.britannica.com/55/190455-050-E617F64E/Night-view-Singapore.jpg',
#   'content': '\ue000Singapore\ue001 | Facts, Geography, History, & Points of Interest | Britannica',
#   'title': 'Singapore | Facts, Geography, History, & Points of Interest | Britannica',
#   'source': 'Britannica',
#   'resolution': '1600×679',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.britannica.com',
#    '/place/Singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [3],
#   'score': 0.3333333333333333,
#   'category': 'images'},
#  {'url': 'https://www.youtube.com/watch?v=-wwW3wLNFAY',
#   'title': 'SINGAPORE TRAVEL (2025) | 15 Awesome Things To Do In Singapore (+ Hidden Gems & Travel Tips)',
#   'content': 'SINGAPORE TRAVEL (2025) | 15 Awesome ...',
#   'source': 'YouTube (319KB)',
#   'resolution': '1280 x 720',
#   'img_src': 'https://i.ytimg.com/vi/-wwW3wLNFAY/maxresdefault.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSzvjJp1U9oPySeNRQqBuhIyiPfyETNfmGRtxaxmzqxGSe59kY&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.youtube.com',
#    '/watch',
#    '',
#    'v=-wwW3wLNFAY',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [3],
#   'score': 0.3333333333333333,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/30766977@N00/54393157844',
#   'img_src': '//live.staticflickr.com/65535/54393157844_a26aafab52_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54393157844_a26aafab52_n.jpg',
#   'source': 'Robstours @ Flickr',
#   'resolution': '800 x 309',
#   'template': 'images.html',
#   'author': 'Rob Lucas',
#   'title': 'singapore',
#   'content': '',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/30766977@N00/54393157844',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [3],
#   'score': 0.3333333333333333,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.travelscout24.de/staedtereisen/singapur/',
#   'title': 'Städtereisen Singapur - günstig bei Travelscout buchen',
#   'content': '',
#   'img_src': 'https://www.travelscout24.de/wp-content/uploads/sites/14/singapur-scaled.jpeg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse4.mm.bing.net%2Fth%2Fid%2FOIP.TGCqXhnoy4Y8aIm87lls4wHaEK%3Fr%3D0%26pid%3DApi&sp=1755935022T4acc4d908c20e644f88ce533fe74cd78c5650392e3640d1d0b937a3914fb9aa7',
#   'resolution': '2560x1438',
#   'img_format': 'jpeg',
#   'filesize': '1.14 MB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'www.travelscout24.de',
#    '/staedtereisen/singapur/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [3],
#   'score': 0.3333333333333333,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://ontheworldmap.com/singapore/singapore-location-map.html',
#   'thumbnail_src': 'https://ts2.mm.bing.net/th?id=OIP.ZSM9cB1LrTKaLC0WEcqC3wHaEa&pid=15.1',
#   'img_src': 'http://ontheworldmap.com/singapore/singapore-location-map.jpg',
#   'content': '\ue000Singapore\ue001 location on the World Map',
#   'title': 'Singapore location on the World Map',
#   'source': 'ontheworldmap.com',
#   'resolution': '2000×1193',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'ontheworldmap.com',
#    '/singapore/singapore-location-map.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [15, 11],
#   'score': 0.3151515151515152,
#   'category': 'images',
#   'filesize': '524.50 KB'},
#  {'template': 'images.html',
#   'url': 'https://creativeplanning.com/international/insights/us-expats-in-singapore/',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.BoEWoPBbPx4p4o0wL1M-bgHaD4&pid=15.1',
#   'img_src': 'https://creativeplanning.com/wp-content/uploads/2023/02/AdobeStock-275094856-Singapore-1200x630-1.jpg',
#   'content': '6 Things You Should Know as a U.S. Expat Living in \ue000Singapore\ue001',
#   'title': '6 Things You Should Know as a U.S. Expat Living in Singapore',
#   'source': 'creativeplanning.com',
#   'resolution': '1200×630',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'creativeplanning.com',
#    '/international/insights/us-expats-in-singapore/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [20, 13],
#   'score': 0.25384615384615383,
#   'category': 'images',
#   'filesize': '208.85 KB'},
#  {'url': 'https://www.pelago.com/en-SG/singapore-things-to-do-l23130/',
#   'title': 'Things to do in Singapore 2025 | Pelago by Singapore Airlines',
#   'content': 'Things to do in Singapore 2025 | Pelago ...',
#   'source': 'Pelago (3.2MB)',
#   'resolution': '3840 x 2664',
#   'img_src': 'https://www.pelago.com/img/destinations/singapore/1023-1702_singapore2.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQm7ZnxABFalAg0SeBHVsTA5PQDxlT7qA7WCi5JOXAIXfAFfHCj&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.pelago.com',
#    '/en-SG/singapore-things-to-do-l23130/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [4],
#   'score': 0.25,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/92362027@N00/54094084367',
#   'img_src': '//live.staticflickr.com/65535/54094084367_a5f58353de_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54094084367_a5f58353de_n.jpg',
#   'source': 'Tridacna @ Flickr',
#   'resolution': '800 x 380',
#   'template': 'images.html',
#   'author': 'Ba Ra',
#   'title': 'Singapore',
#   'content': '',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/92362027@N00/54094084367',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [4],
#   'score': 0.25,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://maps-singapore.com/map-of-singapore-in-asia',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.LMTWtptDusZeN7jXSNUfZgHaGl&pid=15.1',
#   'img_src': 'http://maps-singapore.com/img/1200/map-of-singapore-in-asia.jpg',
#   'content': 'Map of \ue000Singapore\ue001 in asia - \ue000Singapore\ue001 asia map (Republic of \ue000Singapore\ue001)',
#   'title': 'Map of Singapore in asia - Singapore asia map (Republic of Singapore)',
#   'source': 'maps-singapore.com',
#   'resolution': '1200×1067',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'maps-singapore.com',
#    '/map-of-singapore-in-asia',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [23, 14],
#   'score': 0.22981366459627328,
#   'category': 'images',
#   'filesize': '163.55 KB'},
#  {'url': 'https://timesofindia.indiatimes.com/travel/things-to-do/5-days-in-singapore-must-visit-attractions-only/photostory/90660127.cms',
#   'title': '5 days in Singapore: Must-visit attractions only | Times of ...',
#   'content': '5 days in Singapore: Must-visit ...',
#   'source': 'The Times of India (72KB)',
#   'resolution': '748 x 499',
#   'img_src': 'https://static.toiimg.com/thumb/msid-90660347,width-748,height-499,resizemode=4,imgsize-145460/5-days-in-Singapore-Must-visit-attractions-only.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrhxXwekV7-2c6GDzUe4Woim2NQYxe5ENTVnolZK_qiz_sqqQ&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'timesofindia.indiatimes.com',
#    '/travel/things-to-do/5-days-in-singapore-must-visit-attractions-only/photostory/90660127.cms',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [5],
#   'score': 0.2,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/92362027@N00/54073857791',
#   'img_src': '//live.staticflickr.com/65535/54073857791_bb4657b212_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54073857791_bb4657b212_n.jpg',
#   'source': 'Tridacna @ Flickr',
#   'resolution': '800 x 555',
#   'template': 'images.html',
#   'author': 'Ba Ra',
#   'title': 'Singapore',
#   'content': '',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/92362027@N00/54073857791',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [5],
#   'score': 0.2,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://fity.club/lists/suggestions/singapore/',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.KrJFNsZG9XjQGOokJdMobQHaE7&pid=15.1',
#   'img_src': 'https://a.cdn-hotels.com/gdcs/production93/d422/118f3050-41af-4c7b-9651-3428a0e894d9.jpg',
#   'content': '\ue000Singapore\ue001',
#   'title': 'Singapore',
#   'source': 'fity.club',
#   'resolution': '1600×1066',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'fity.club',
#    '/lists/suggestions/singapore/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [28, 16],
#   'score': 0.19642857142857142,
#   'category': 'images',
#   'filesize': '453.01 KB'},
#  {'template': 'images.html',
#   'url': 'https://www.fotolip.com/map-of-singapore-6244.html',
#   'thumbnail_src': 'https://ts2.mm.bing.net/th?id=OIP.o35vbW9HQu7TLM_XginkggHaFC&pid=15.1',
#   'img_src': 'https://www.fotolip.com/wp-content/uploads/2016/05/Map-of-Singapore-2.jpg',
#   'content': 'Map of \ue000Singapore\ue001 - Fotolip',
#   'title': 'Map of Singapore - Fotolip',
#   'source': 'fotolip.com',
#   'resolution': '2500×1699',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.fotolip.com',
#    '/map-of-singapore-6244.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [21, 24],
#   'score': 0.17857142857142855,
#   'category': 'images',
#   'filesize': '2.04 MB'},
#  {'template': 'images.html',
#   'url': 'https://www.tripsavvy.com/travel-journal-three-days-in-singapore-993200',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.wZHCD6w-OQIJ-qaEj9pghwHaE8&pid=15.1',
#   'img_src': 'https://fthmb.tqn.com/VbuNfLcdgII-GlZYtPDMZoymPBw=/4500x3001/filters:fill(auto,1)/singapore-travel-584f789f5f9b58a8cdf97dda.jpg',
#   'content': '\ue000Singapore\ue001 Travel: Essentials to Know',
#   'title': 'Singapore Travel: Essentials to Know',
#   'source': 'TripSavvy',
#   'resolution': '4500×3001',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.tripsavvy.com',
#    '/travel-journal-three-days-in-singapore-993200',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [6],
#   'score': 0.16666666666666666,
#   'category': 'images'},
#  {'url': 'https://en.wikipedia.org/wiki/Central_Region,_Singapore',
#   'title': 'Central Region, Singapore - Wikipedia',
#   'content': '',
#   'source': 'en.wikipedia.org (27KB)',
#   'resolution': '330 x 220',
#   'img_src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Marina_Bay_Singapore-3499.jpg/330px-Marina_Bay_Singapore-3499.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ3YQYT7jHkXfr_qJ9QnPM_Hbm_0HzaW--Rt3vIcTRiw1jYvmj3&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'en.wikipedia.org',
#    '/wiki/Central_Region,_Singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [6],
#   'score': 0.16666666666666666,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/92362027@N00/54074313130',
#   'img_src': '//live.staticflickr.com/65535/54074313130_405a388a3c_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54074313130_405a388a3c_n.jpg',
#   'source': 'Tridacna @ Flickr',
#   'resolution': '568 x 800',
#   'template': 'images.html',
#   'author': 'Ba Ra',
#   'title': 'Singapore',
#   'content': '',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/92362027@N00/54074313130',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [6],
#   'score': 0.16666666666666666,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://lkyspp.nus.edu.sg/gia/article/international-politics-in-asia-looking-beyond-china',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.0e0JF_70sP9EcZ_6M3ik_AHaEo&pid=15.1',
#   'img_src': 'https://lkyspp.nus.edu.sg/images/default-source/gia-images/singaporecap.jpg?sfvrsn=5ed57f0a_0',
#   'content': '',
#   'title': 'International Politics in Asia: Looking beyond China',
#   'source': 'Lee Kuan Yew School of Public Policy',
#   'resolution': '3992×2495',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'lkyspp.nus.edu.sg',
#    '/gia/article/international-politics-in-asia-looking-beyond-china',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [27, 23],
#   'score': 0.1610305958132045,
#   'category': 'images',
#   'filesize': '1.54 MB'},
#  {'url': 'https://www.marinabaysands.com/guides.html',
#   'title': 'Singapore Travel Guide | Blog | Marina Bay Sands',
#   'content': 'Singapore Travel Guide | Blog | Marina ...',
#   'source': 'Marina Bay Sands (348KB)',
#   'resolution': '1080 x 1440',
#   'img_src': 'https://www.marinabaysands.com/content/dam/marinabaysands/guides/masthead-m.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDHhtBt7dxuFM1s4Bwb2GoIWCFcodK2NtesG16vGti2AgYk8cY&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.marinabaysands.com',
#    '/guides.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [7],
#   'score': 0.14285714285714285,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/35757099@N06/54428344194',
#   'img_src': '//live.staticflickr.com/65535/54428344194_b558b7a543_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54428344194_b558b7a543_n.jpg',
#   'source': 'AntEater Theater @ Flickr',
#   'resolution': '800 x 532',
#   'template': 'images.html',
#   'author': 'Aaron Aardvark',
#   'title': 'Singapore',
#   'content': '(Instagram)',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/35757099@N06/54428344194',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [7],
#   'score': 0.14285714285714285,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://wallpaperaccess.com/singapore-skyline',
#   'title': 'Singapore Skyline Wallpapers - Top Free Singapore Skyline Backgrounds - WallpaperAccess',
#   'content': '',
#   'img_src': 'https://wallpaperaccess.com/full/328442.jpg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse4.mm.bing.net%2Fth%2Fid%2FOIP.f5rZR8lXE5E-mFHI_TVEJAHaEo%3Fr%3D0%26pid%3DApi&sp=1755935022T4289ff1fded3d630a7a3ae485b7f1e941136f16b8187a759f99af9bec427c816',
#   'resolution': '2560x1600',
#   'img_format': 'jpeg',
#   'filesize': '440.08 KB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'wallpaperaccess.com',
#    '/singapore-skyline',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [7],
#   'score': 0.14285714285714285,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://maps-singapore.com/singapore-in-world-map',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.F0u3q485oyyqeBKULfah8wHaDv&pid=15.1',
#   'img_src': 'http://maps-singapore.com/img/0/singapore-in-world-map.jpg',
#   'content': '\ue000Singapore\ue001 in world map - \ue000Singapore\ue001 world map (Republic of \ue000Singapore\ue001)',
#   'title': 'Singapore in world map - Singapore world map (Republic of Singapore)',
#   'source': 'maps-singapore.com',
#   'resolution': '1134×572',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'maps-singapore.com',
#    '/singapore-in-world-map',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [25, 39],
#   'score': 0.13128205128205128,
#   'category': 'images',
#   'filesize': '81.70 KB'},
#  {'template': 'images.html',
#   'url': 'https://www.thoughtco.com/where-is-singapore-1458491',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.02bF2ykBjGj5aBWF7krv4wHaE8&pid=15.1',
#   'img_src': 'https://www.thoughtco.com/thmb/h2rufV1n9LVbA4jaOzXUuJMATVw=/2121x1414/filters:fill(auto,1)/singapore--garden-by-the-bay--supertree-grove-638256268-fa59e7e78b6449aaa40f68eafe6ff1a1.jpg',
#   'content': 'Where Is \ue000Singapore\ue001? Tips for First-Time Visitors',
#   'title': 'Where Is Singapore? Tips for First-Time Visitors',
#   'source': 'ThoughtCo',
#   'resolution': '2121×1414',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.thoughtco.com',
#    '/where-is-singapore-1458491',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [8],
#   'score': 0.125,
#   'category': 'images'},
#  {'url': 'https://en.wikipedia.org/wiki/Singapore',
#   'title': 'Singapore - Wikipedia',
#   'content': '',
#   'source': 'Wikipedia, the free encyclopedia (80KB)',
#   'resolution': '960 x 253',
#   'img_src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Marina_Bay%2C_Financial_District_and_Singapore_River_%2835622190292%29.jpg/960px-Marina_Bay%2C_Financial_District_and_Singapore_River_%2835622190292%29.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQP6BC13KYado_vjBUPQiptd60CjFDjjK1gvd6zGMryd6sx0G3J&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https', 'en.wikipedia.org', '/wiki/Singapore', '', '', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [8],
#   'score': 0.125,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/77428038@N00/54712637678',
#   'img_src': '//live.staticflickr.com/65535/54712637678_09d8eaf8ce_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54712637678_09d8eaf8ce_n.jpg',
#   'source': 'haegar52002 @ Flickr',
#   'resolution': '600 x 800',
#   'template': 'images.html',
#   'author': 'Stefan Unger',
#   'title': 'Singapore',
#   'content': 'Arabic quarter',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/77428038@N00/54712637678',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [8],
#   'score': 0.125,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://www.travel-link.in/?p=168',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.YeiHizV6MoCOSUkV1dMKcQHaEK&pid=15.1',
#   'img_src': 'http://www.travel-link.in/wp-content/uploads/2015/10/singapore-....jpg',
#   'content': '\ue000Singapore\ue001 with Cruise | 3Nights \ue000Singapore\ue001 and 2 Nights Cruise ...',
#   'title': 'Singapore with Cruise | 3Nights Singapore and 2 Nights Cruise – Travellink | Tailor Made Travel',
#   'source': 'travel-link.in',
#   'resolution': '1920×1080',
#   'img_format': 'jpeg',
#   'engine': 'bing images',
#   'parsed_url': ['http', 'www.travel-link.in', '/', '', 'p=168', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images', 'bing images'],
#   'positions': [36, 31],
#   'score': 0.12007168458781362,
#   'category': 'images',
#   'filesize': '597.68 KB'},
#  {'template': 'images.html',
#   'url': 'https://diplomatic-council.org/news-and-events/news/investment-hub-singapore',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.M90XIpJcDJ6GNvwPvp9jngHaEK&pid=15.1',
#   'img_src': 'https://www.diplomatic-council.org/sites/default/files/2021-04/Grand-Hyatt-Singapore-P615-Esplanade.16x9.jpg',
#   'content': 'Investment Hub \ue000Singapore\ue001 | Diplomatic Council',
#   'title': 'Investment Hub Singapore | Diplomatic Council',
#   'source': 'diplomatic-council.org',
#   'resolution': '2560×1440',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'diplomatic-council.org',
#    '/news-and-events/news/investment-hub-singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [9],
#   'score': 0.1111111111111111,
#   'category': 'images'},
#  {'url': 'https://www.introducingsingapore.com/',
#   'title': 'Singapore - Introducing Singapore travel guide',
#   'content': 'Introducing Singapore travel ...',
#   'source': 'www.introducingsingapore.com (107KB)',
#   'resolution': '1600 x 537',
#   'img_src': 'https://www.introducingsingapore.com/f/singapur/singapur/guia/singapur.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWlhzquuj0jtCgmVyJROQIIiUPCARMeX2HyR6BviBN5ee5Ghs&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https', 'www.introducingsingapore.com', '/', '', '', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [9],
#   'score': 0.1111111111111111,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/92362027@N00/54075320297',
#   'img_src': '//live.staticflickr.com/65535/54075320297_6ce3fd127e_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54075320297_6ce3fd127e_n.jpg',
#   'source': 'Tridacna @ Flickr',
#   'resolution': '800 x 564',
#   'template': 'images.html',
#   'author': 'Ba Ra',
#   'title': 'Singapore',
#   'content': '',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/92362027@N00/54075320297',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [9],
#   'score': 0.1111111111111111,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://in.pinterest.com/pin/698409854752226003/',
#   'title': 'Merlion, Singapore | Singapore tour, Holiday in singapore, Singapore travel',
#   'content': '',
#   'img_src': 'https://i.pinimg.com/originals/de/db/8a/dedb8a168af58b7a3c8f64a66b9ba9f7.jpg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse2.mm.bing.net%2Fth%2Fid%2FOIP.8AQv7N3vtigguXP9JRrCrQHaHa%3Fr%3D0%26pid%3DApi&sp=1755935022Tb59de93f5e638abf9bb6101efad78ccf26a986ef020aa1fbb9e3e8ac9ba5db0c',
#   'resolution': '800x800',
#   'img_format': 'jpeg',
#   'filesize': '147.12 KB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'in.pinterest.com',
#    '/pin/698409854752226003/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [9],
#   'score': 0.1111111111111111,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': '',
#   'thumbnail_src': '',
#   'img_src': 'https://live.staticflickr.com/1659/24618687070_7bd7484136_b.jpg',
#   'content': None,
#   'title': '',
#   'source': '',
#   'resolution': '',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': None,
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [10],
#   'score': 0.1,
#   'category': 'images'},
#  {'url': 'https://gocity.com/en/singapore/things-to-do/what-is-singapore-best-known-for',
#   'title': 'What is Singapore Best Known For | Go City®',
#   'content': '',
#   'source': 'Go City (994KB)',
#   'resolution': '3840 x 2880',
#   'img_src': 'https://res.cloudinary.com/dtljonz0f/image/upload/c_auto,ar_4:3,w_3840,g_auto/f_auto/q_auto/v1/gc-v1/singapore/go-city-singapore?_a=BAVAZGE70',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzZPQlidw-lrjrYAesn5K5R-6mrG05NcHzwuF6E9SwW9NEHzI&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'gocity.com',
#    '/en/singapore/things-to-do/what-is-singapore-best-known-for',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [10],
#   'score': 0.1,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/202698118@N08/54479368929',
#   'img_src': '//live.staticflickr.com/65535/54479368929_26f6669bac_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54479368929_26f6669bac_n.jpg',
#   'source': 'sogoranai @ Flickr',
#   'resolution': '800 x 534',
#   'template': 'images.html',
#   'author': 'sogoranai',
#   'title': 'Singapore',
#   'content': '',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/202698118@N08/54479368929',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [10],
#   'score': 0.1,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://uncoversixtyfive.com/five-reasons-to-visit-marina-bay-sands-singapore/',
#   'title': '5 Reasons Why You Should Visit Marina Bay Sands in Singapore - Uncover65 - Explore Singapore',
#   'content': '',
#   'img_src': 'https://esmzwrjnedz.exactdn.com/wp-content/uploads/2021/10/shutterstock_350484137-min-1.jpg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.bZ3UGXkghBj4yCZzkjSgCQHaE8%3Fr%3D0%26pid%3DApi&sp=1755935022T6e75cb41680182f55537069d1b066791c3f292972ddefbb13ed99582dfae26cf',
#   'resolution': '1200x800',
#   'img_format': 'jpeg',
#   'filesize': '169.70 KB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'uncoversixtyfive.com',
#    '/five-reasons-to-visit-marina-bay-sands-singapore/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [10],
#   'score': 0.1,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.independent.co.uk/travel/asia/singapore/singapore-guide-best-things-to-do-eat-stay-b2325821.html',
#   'thumbnail_src': 'https://ts1.mm.bing.net/th?id=OIP.PTosa6jiSHPGUPjA4LDkxwHaFj&pid=15.1',
#   'img_src': 'https://static.independent.co.uk/2023/04/25/07/newFile.jpg?quality=75&width=1200&auto=webp',
#   'content': '\ue000Singapore\ue001 travel guide: Everything you need to know before you go | The ...',
#   'title': 'Singapore travel guide: Everything you need to know before you go | The ...',
#   'source': 'www.independent.co.uk',
#   'resolution': '1200×901',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['https',
#    'www.independent.co.uk',
#    '/travel/asia/singapore/singapore-guide-best-things-to-do-eat-stay-b2325821.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [11],
#   'score': 0.09090909090909091,
#   'category': 'images'},
#  {'url': 'https://www.cntraveler.com/destinations/singapore',
#   'title': 'Singapore Travel Guide & Tips | Condé Nast Traveler',
#   'content': 'Singapore Travel Guide & Tips | Condé ...',
#   'source': 'Condé Nast Traveler (252KB)',
#   'resolution': '1280 x 1280',
#   'img_src': "https://media.cntraveler.com/photos/6123f125d1a820e0a0f54b37/1:1/w_1280%2Ch_1280%2Cc_limit/LICENSE_Damian%2520D'Silva-singapore_(c)%2520Getty%2520Images_CNT%2520UK_Sophie%2520Knight.jpeg",
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFdgCTzuD7hjAnbBoWc8CEVEE-IR_-A45MAKOClPbOPuYW0wT_&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.cntraveler.com',
#    '/destinations/singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [11],
#   'score': 0.09090909090909091,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/52376059@N02/54223069097',
#   'img_src': '//live.staticflickr.com/65535/54223069097_2b5e47aa28_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54223069097_2b5e47aa28_n.jpg',
#   'source': 'UltraPanavision @ Flickr',
#   'resolution': '800 x 534',
#   'template': 'images.html',
#   'author': 'Adrian Turner',
#   'title': 'Singapore',
#   'content': 'The Singapore skyline at Marina Bay.',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/52376059@N02/54223069097',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [11],
#   'score': 0.09090909090909091,
#   'category': 'images'},
#  {'url': 'https://www.goway.com/destinations/asia/singapore/trips/taste-singapore',
#   'title': '5 Day Singapore Vacation | Visit Chinatown, Katong & More | Goway',
#   'content': '5 Day Singapore Vacation | Visit ...',
#   'source': 'Goway Travel (5.2MB)',
#   'resolution': '7088 x 4037',
#   'img_src': 'https://images.goway.com/production/hero_image/Merlion%20Park%20SingaporeAdobeStock_760539307.jpeg?VersionId=WwvL1smrTixBaZrnO4qqYV8leDTFYuKL',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT0ydvqkDrGqRfXZsD21E_5vZI702SDEW5e0G2B3J9GHVKiJp4&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.goway.com',
#    '/destinations/asia/singapore/trips/taste-singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [12],
#   'score': 0.08333333333333333,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/52376059@N02/54234919515',
#   'img_src': '//live.staticflickr.com/65535/54234919515_1e0b80caf7_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54234919515_1e0b80caf7_n.jpg',
#   'source': 'UltraPanavision @ Flickr',
#   'resolution': '800 x 532',
#   'template': 'images.html',
#   'author': 'Adrian Turner',
#   'title': 'Singapore',
#   'content': 'The city skyline seen through the dome at Gardens By the Bay in Singapore.',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/52376059@N02/54234919515',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [12],
#   'score': 0.08333333333333333,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.holidify.com/places/singapore/',
#   'title': 'Singapore Tourism (2025) Travel Guide Top Places | Holidify',
#   'content': '',
#   'img_src': 'https://www.holidify.com/images/bgImages/SINGAPORE.jpg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse1.mm.bing.net%2Fth%2Fid%2FOIP.LE_ldmOFyB455IkPgwaZoQHaE8%3Fr%3D0%26pid%3DApi&sp=1755935022T2e6be8d8d9554be73ef5cb3c28b4f2d9939ab94cd79b001c362f0ac834523ff3',
#   'resolution': '1000x667',
#   'img_format': 'jpeg',
#   'filesize': '82.71 KB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'www.holidify.com',
#    '/places/singapore/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [12],
#   'score': 0.08333333333333333,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://www.qantas.com/travelinsider/en/travel-tips/here-s-what-not-to-do-in-singapore.html',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.qLwVVHsaIHTn-zb2tj9X_gHaE7&pid=15.1',
#   'img_src': 'https://www.qantas.com/content/dam/travelinsider/images/travel-tips/here-s-what-not-to-do-in-singapore/iStock-590050726.jpg',
#   'content': 'How to See Another Side of \ue000Singapore\ue001 | Travel Insider',
#   'title': 'How to See Another Side of Singapore | Travel Insider',
#   'source': 'qantas.com',
#   'resolution': '5000×3333',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'www.qantas.com',
#    '/travelinsider/en/travel-tips/here-s-what-not-to-do-in-singapore.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [13],
#   'score': 0.07692307692307693,
#   'category': 'images'},
#  {'url': 'https://nus.edu.sg/',
#   'title': 'NUS - National University of Singapore',
#   'content': '',
#   'source': 'nus.edu.sg | a day ago (247KB)',
#   'resolution': '960 x 540',
#   'img_src': 'https://nus.edu.sg/images/default-source/corporate/homepage-refresh/20250821/tl1.jpg?t=1755847916',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS17GsnEbmfJxLom2mbI73QZvLOKzIzwDiT5mNvpl4pZMW_9oFk&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https', 'nus.edu.sg', '/', '', '', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [13],
#   'score': 0.07692307692307693,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/52376059@N02/54238940413',
#   'img_src': '//live.staticflickr.com/65535/54238940413_026ebe6704_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54238940413_026ebe6704_n.jpg',
#   'source': 'UltraPanavision @ Flickr',
#   'resolution': '800 x 532',
#   'template': 'images.html',
#   'author': 'Adrian Turner',
#   'title': 'Singapore',
#   'content': "The Marina Bay Sands Hotel seen through the Cloud Forest Dome at Gardens By the Bay. It's all very Fritz Lang.",
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/52376059@N02/54238940413',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [13],
#   'score': 0.07692307692307693,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'http://www.travelzoo.com/blog/singapore-3-days/',
#   'thumbnail_src': 'https://ts3.mm.bing.net/th?id=OIP.cxOgtVsckDgkWk0-JxJ51QHaDt&pid=15.1',
#   'img_src': 'https://ssl.tzoo-img.com/images/tzoo.18886.0.651788.Singapore.jpg',
#   'content': 'Why You Need to Stop & See \ue000Singapore\ue001: a 1-, 2- or 3-Day Guide | Travelzoo',
#   'title': 'Why You Need to Stop & See Singapore: a 1-, 2- or 3-Day Guide | Travelzoo',
#   'source': 'www.travelzoo.com',
#   'resolution': '1500×750',
#   'img_format': None,
#   'engine': 'bing images',
#   'parsed_url': ['http',
#    'www.travelzoo.com',
#    '/blog/singapore-3-days/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['bing images'],
#   'positions': [14],
#   'score': 0.07142857142857142,
#   'category': 'images'},
#  {'url': 'https://geographical.co.uk/news/country-profile-singapore',
#   'title': 'Country profile: Singapore - Geographical',
#   'content': '',
#   'source': 'Geographical Magazine (194KB)',
#   'resolution': '750 x 500',
#   'img_src': 'https://geographical.co.uk/wp-content/uploads/singapore-1.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKaFSuJnQ9_eTk4Kl85WmKsiOIuKnJaBO9Ij3VCWXDyLduI7E&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'geographical.co.uk',
#    '/news/country-profile-singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [14],
#   'score': 0.07142857142857142,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/55784989@N02/54333426615',
#   'img_src': '//live.staticflickr.com/65535/54333426615_5a7164f8a3_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54333426615_5a7164f8a3_n.jpg',
#   'source': 'adriandc2010 @ Flickr',
#   'resolution': '550 x 800',
#   'template': 'images.html',
#   'author': 'Adrian cook',
#   'title': 'Singapore',
#   'content': 'The back streets behind the restaurants',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/55784989@N02/54333426615',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [14],
#   'score': 0.07142857142857142,
#   'category': 'images'},
#  {'url': 'https://www.tripadvisor.com/Attractions-g294265-Activities-Singapore.html',
#   'title': 'THE 15 BEST Things to Do in Singapore (2025) - Must-See ...',
#   'content': 'THE 15 BEST Things to Do in Singapore ...',
#   'source': 'Tripadvisor (133KB)',
#   'resolution': '1200 x 609',
#   'img_src': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/33/fc/b1/singapore.jpg?w=1200&h=700&s=1',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRolme-g29aj0A_Huhw7QPU4HWWe6mbtm_5mOq2k13dcUsAo-U&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.tripadvisor.com',
#    '/Attractions-g294265-Activities-Singapore.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [15],
#   'score': 0.06666666666666667,
#   'category': 'images'},
#  {'url': 'https://www.flickr.com/photos/77585122@N00/54388263620',
#   'img_src': '//live.staticflickr.com/65535/54388263620_a477a64fb0_c.jpg',
#   'thumbnail_src': '//live.staticflickr.com/65535/54388263620_a477a64fb0_n.jpg',
#   'source': 'joka2000 @ Flickr',
#   'resolution': '800 x 534',
#   'template': 'images.html',
#   'author': '',
#   'title': 'Singapore Marina Bay Sands',
#   'content': 'Singapore',
#   'engine': 'flickr',
#   'parsed_url': ['https',
#    'www.flickr.com',
#    '/photos/77585122@N00/54388263620',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['flickr'],
#   'positions': [15],
#   'score': 0.06666666666666667,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.britannica.com/place/Singapore/The-people',
#   'title': 'Singapore - Multicultural, Diverse, Cosmopolitan | Britannica',
#   'content': '',
#   'img_src': 'https://cdn.britannica.com/36/156336-050-6F029914/business-district-buildings-Singapore-structures-foreground.jpg',
#   'thumbnail_src': 'https://www.startpage.com/av/proxy-image?piurl=https%3A%2F%2Ftse4.mm.bing.net%2Fth%2Fid%2FOIP.sgliJ-uuiW04TtPozDt09wHaFg%3Fr%3D0%26pid%3DApi&sp=1755935022Tda603c48984cca3f5eb567b1b2e14532c968e631c5153aefbff5a48bb7a842eb',
#   'resolution': '1600x1190',
#   'img_format': 'jpeg',
#   'filesize': '486.43 KB',
#   'engine': 'startpage images',
#   'parsed_url': ['https',
#    'www.britannica.com',
#    '/place/Singapore/The-people',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['startpage images'],
#   'positions': [15],
#   'score': 0.06666666666666667,
#   'category': 'images'},
#  {'template': 'images.html',
#   'url': 'https://www.hotels.com/go/singapore',
#   'thumbnail_src': 'https://ts4.mm.bing.net/th?id=OIP.2agDO5ebFKJmzUzrUzdLWAHaE8&pid=15.1',
#   'img_src': 'https://a.cdn-hotels.com/gdcs/production8/d1098/064a4e00-23ee-4137-8ec3-a0d27bca0782.jpg',
#   'content': '\ue000Singapore\ue001 - What you need to know before you go – Go Guides',
#   'title': 'Singapore - What you need to know before you go – Go Guides',
#   'source': 'www.hotels.com',
# ...
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.klook.com',
#    '/blog/singapore-oceanarium-guide/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [82],
#   'score': 0.012195121951219513,
#   'category': 'images'},
#  {'url': 'https://www.getyourguide.com/singapore-l170/singapore-starry-night-cruise-garden-rhapsody-spectra-t712172/',
#   'title': 'Singapore Starry Night: Cruise, Garden Rhapsody, & Spectra ...',
#   'content': 'Singapore Starry Night: Cruise, Garden ...',
#   'source': 'GetYourGuide (118KB)',
#   'resolution': '900 x 900',
#   'img_src': 'https://cdn.getyourguide.com/image/format=auto,fit=crop,gravity=auto,quality=60,width=450,height=450,dpr=2/tour_img/f1fd2ba460e20514dafdbbaaea8981659ca3696121f2725f19b9fceb79779a2a.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgik6eD7ofHDsfOIxO5Zkm0F3IGeOVR-L1nFdmDhNQ-nEph_P8&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.getyourguide.com',
#    '/singapore-l170/singapore-starry-night-cruise-garden-rhapsody-spectra-t712172/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [83],
#   'score': 0.012048192771084338,
#   'category': 'images'},
#  {'url': 'https://www.travelweekly.com/Hotels/Singapore-Singapore/Marina-Bay-Sands-Singapore-p4050094',
#   'title': 'Marina Bay Sands, Singapore- Deluxe Singapore, Singapore ...',
#   'content': 'Marina Bay Sands, Singapore- Deluxe ...',
#   'source': 'Travel Weekly (85KB)',
#   'resolution': '780 x 437',
#   'img_src': 'https://ik.imgkit.net/3vlqs5axxjf/external/ik-seo/https://www.cfmedia.vfmleonardo.com/imageRepo/2/0/186/208/259/20240826_Exterior_Architecture-17_O/Marina-Bay-Sands-Singapore-Exterior.jpg?tr=w-780%2Ch-437%2Cfo-auto',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0cxa_ARovN61fCL3axxDufe2AIJwKsaNdYeFZqLSxMOfuNiIi&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.travelweekly.com',
#    '/Hotels/Singapore-Singapore/Marina-Bay-Sands-Singapore-p4050094',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [84],
#   'score': 0.011904761904761904,
#   'category': 'images'},
#  {'url': 'https://www.stb.gov.sg/about-stb/media-publications/media-centre/singapore-tourism-board-launches-made-in-singapore-global-campaign-to-inspire-travel-to-singapore',
#   'title': 'Singapore Tourism Board launches Made in Singapore global ...',
#   'content': 'Singapore Tourism Board launches Made ...',
#   'source': 'Singapore Tourism Board (393KB)',
#   'resolution': '960 x 647',
#   'img_src': 'https://isomer-user-content.by.gov.sg/1/275acc5c-37e4-410e-8e26-e1cb5dba749f/Made%20in%20Singapore.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSl3mcveG_gWtTQjy0xhteXnI69m0QJpDPCYL9_45BFYaM_eMc&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.stb.gov.sg',
#    '/about-stb/media-publications/media-centre/singapore-tourism-board-launches-made-in-singapore-global-campaign-to-inspire-travel-to-singapore',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [85],
#   'score': 0.011764705882352941,
#   'category': 'images'},
#  {'url': 'https://www.tripadvisor.com/Hotel_Review-g294265-d593661-Reviews-Wyndham_Singapore_Hotel-Singapore.html',
#   'title': 'WYNDHAM SINGAPORE HOTEL - Updated 2025 Prices & Reviews',
#   'content': 'WYNDHAM SINGAPORE HOTEL - Updated 2025 ...',
#   'source': 'Tripadvisor (100KB)',
#   'resolution': '900 x 500',
#   'img_src': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/4b/a1/11/exterior.jpg?w=900&h=500&s=1',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRs6_nQ3cXw_6OQecGPs0bqL8l5IhikQ_krKBOSclWvDyyyDCm0&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.tripadvisor.com',
#    '/Hotel_Review-g294265-d593661-Reviews-Wyndham_Singapore_Hotel-Singapore.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [86],
#   'score': 0.011627906976744186,
#   'category': 'images'},
#  {'url': 'https://www.nhb.gov.sg/nationalmuseum/',
#   'title': 'National Museum of Singapore',
#   'content': '',
#   'source': 'www.nhb.gov.sg | 21 hours ago (172KB)',
#   'resolution': '800 x 800',
#   'img_src': 'https://www.nhb.gov.sg/nationalmuseum/-/media/nms2024/slides/homepage/snf-mobile.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7wP-Fz-eJT3WFRxZtzQL_aU3NieLLvFnapceQIVzCo9-hPz0&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https', 'www.nhb.gov.sg', '/nationalmuseum/', '', '', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [87],
#   'score': 0.011494252873563218,
#   'category': 'images'},
#  {'url': 'https://www.topuniversities.com/where-to-study/asia/singapore/guide',
#   'title': 'Study in Singapore | Top Universities',
#   'content': '',
#   'source': 'Top Universities (26KB)',
#   'resolution': '489 x 202',
#   'img_src': 'https://www.topuniversities.com/sites/default/files/styles/489x202/public/guides/lead-bg-images/file%20%2846%29.jpg.webp',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR45cFR26kD-pBlm82bTYKyKC2RstHkYtkxWbbLXEnQBzFecNI1&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.topuniversities.com',
#    '/where-to-study/asia/singapore/guide',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [88],
#   'score': 0.011363636363636364,
#   'category': 'images'},
#  {'url': 'https://commons.wikimedia.org/wiki/File:Flag_of_Singapore.svg',
#   'title': 'File:Flag of Singapore.svg - Wikimedia Commons',
#   'content': 'File:Flag of Singapore.svg - Wikimedia ...',
#   'source': 'Wikimedia Commons (22KB)',
#   'resolution': '2560 x 1707',
#   'img_src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/2560px-Flag_of_Singapore.svg.png',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMluJiVDcKzYk0m-erLTZKRAt0QHN0faqiJq4tImLnd8jkbIik&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'commons.wikimedia.org',
#    '/wiki/File:Flag_of_Singapore.svg',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [89],
#   'score': 0.011235955056179775,
#   'category': 'images'},
#  {'url': 'https://www.wmras.org.sg/',
#   'title': 'Home - WMRAS | Waste Management and Recycling Association of ...',
#   'content': 'Home - WMRAS | Waste Management and ...',
#   'source': 'www.wmras.org.sg (649KB)',
#   'resolution': '2224 x 780',
#   'img_src': 'https://www.wmras.org.sg/wp-content/uploads/2025/08/WMRAS-Home-01.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsQJK2uud6yME43dF_qzZcPMXpeo3EvN_6Ni8e3-G5RUrd2C0f&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https', 'www.wmras.org.sg', '/', '', '', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [90],
#   'score': 0.011111111111111112,
#   'category': 'images'},
#  {'url': 'https://www.imda.gov.sg/resources/blog/blog-articles/2025/05/rise-of-sg-as-global-tech-hub',
#   'title': 'Singapore Tech Hub: Trends & Opportunities | IMDA',
#   'content': 'Singapore Tech Hub: Trends ...',
#   'source': 'IMDA (78KB)',
#   'resolution': '1217 x 325',
#   'img_src': 'https://www.imda.gov.sg/-/media/imda/images/content/news-and-events/impact-news-2025/05/rise-of-sg-as-global-tech-hub/the-rise-of-sg-as-global-tech-desktop.webp',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRejcs6uBFYtdf4GsqU1iF4DG2nOy3TNmetXnbFWcO-JCLSEiib&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.imda.gov.sg',
#    '/resources/blog/blog-articles/2025/05/rise-of-sg-as-global-tech-hub',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [91],
#   'score': 0.01098901098901099,
#   'category': 'images'},
#  {'url': 'https://www.mandai.com/en/plan-your-visit/maps/singapore-zoo.html',
#   'title': 'Singapore Zoo Park Map | Mandai Wildlife Reserve',
#   'content': 'Singapore Zoo Park Map | Mandai ...',
#   'source': 'Mandai Wildlife Reserve (631KB)',
#   'resolution': '1200 x 1463',
#   'img_src': 'https://www.mandai.com/content/dam/mandai/singapore-zoo/park-map/sz-en-map.png',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQnMgx68KeTHeFHETRFeV4Dl0BhHgaJlcN4oaeKr3myGl6HBS8&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.mandai.com',
#    '/en/plan-your-visit/maps/singapore-zoo.html',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [92],
#   'score': 0.010869565217391304,
#   'category': 'images'},
#  {'url': 'https://www.divessi.com/en/mydiveguide/destination/singapore-9749990',
#   'title': 'Diving in Singapore',
#   'content': '',
#   'source': 'SSI (275KB)',
#   'resolution': '1200 x 800',
#   'img_src': 'https://cdn.divessi.com/cached/Singapur_iStock-TommL.jpg/1200.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSOmlKQbSNYP_HyORez7FdTqW7HiFyir7XgZkYeqLF2PDnZAco&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.divessi.com',
#    '/en/mydiveguide/destination/singapore-9749990',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [93],
#   'score': 0.010752688172043012,
#   'category': 'images'},
#  {'url': 'https://guide.michelin.com/th/en/article/travel/f1-weekend-2025-in-singapore-the-michelin-hotels-with-track-views-close-to-the-heart-of-the-action',
#   'title': 'F1 Weekend 2025 in Singapore: The MICHELIN Hotels with Track ...',
#   'content': 'F1 Weekend 2025 in Singapore: The ...',
#   'source': 'MICHELIN Guide | a day ago (282KB)',
#   'resolution': '1120 x 630',
#   'img_src': 'https://d3h1lg3ksw6i6b.cloudfront.net/media/image/2025/08/22/1a397ed5719f44f09bff028263d693b2_F1_Singapore_2025_Header.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSQlHs_mHcxmoKL-GPCe8zYSIMDjij6s1LS7g3HAVEA25XPqqi&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'guide.michelin.com',
#    '/th/en/article/travel/f1-weekend-2025-in-singapore-the-michelin-hotels-with-track-views-close-to-the-heart-of-the-action',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [94],
#   'score': 0.010638297872340425,
#   'category': 'images'},
#  {'url': 'https://pinandtrip.com/en/ce-sa-faci-in-singapore-top-26-locuri-pe-care-sa-le-vizitezi-in-singapore-itinerar-de-1-2-3-sau-4-zile/',
#   'title': 'What to do in Singapore – TOP 26 places not to be missed + 1 ...',
#   'content': 'What to do in Singapore – TOP 26 places ...',
#   'source': 'Pin & Trip (87KB)',
#   'resolution': '845 x 634',
#   'img_src': 'https://pinandtrip.com/wp-content/uploads/2024/11/IMG_1013-845x634.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpQTkYG9EL8Q1mv76106w18aFCbeOHtdiTXjf56-Ggw94ysIs&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'pinandtrip.com',
#    '/en/ce-sa-faci-in-singapore-top-26-locuri-pe-care-sa-le-vizitezi-in-singapore-itinerar-de-1-2-3-sau-4-zile/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [95],
#   'score': 0.010526315789473684,
#   'category': 'images'},
#  {'url': 'https://www.ihg.com/crowneplaza/hotels/us/en/singapore/sincp/hoteldetail',
#   'title': 'Crowne Plaza Changi Airport - Singapore, Singapore',
#   'content': 'Crowne Plaza Changi Airport - Singapore ...',
#   'source': 'IHG (1.9MB)',
#   'resolution': '3633 x 2725',
#   'img_src': 'https://digital.ihg.com/is/image/ihg/crowne-plaza-singapore-9989207156-4x3',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdcQgViPcJZoVcI9GrtRP04XzQOlo02GlP_MROeN9JV1kZrEiL&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.ihg.com',
#    '/crowneplaza/hotels/us/en/singapore/sincp/hoteldetail',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [96],
#   'score': 0.010416666666666666,
#   'category': 'images'},
#  {'url': 'https://www.cnn.com/2025/07/16/style/singapore-marina-bay-sands-expansion',
#   'title': "Singapore's most famous landmark is undergoing an $8 billion ...",
#   'content': "Singapore's most famous landmark is ...",
#   'source': 'CNN (2.4MB)',
#   'resolution': '5523 x 3675',
#   'img_src': 'https://media.cnn.com/api/v1/images/stellar/prod/gettyimages-1173542966.jpg?c=original',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSQhHYARi-8pk4XEmrGFMtltQm-IMT57v0cB8LqzNzd9Tz8q9s&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.cnn.com',
#    '/2025/07/16/style/singapore-marina-bay-sands-expansion',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [97],
#   'score': 0.010309278350515464,
#   'category': 'images'},
#  {'url': 'https://www.travelodgehotels.asia/best-ways-to-celebrate-singapore-national-day/',
#   'title': 'Best Ways to Celebrate Singapore National Day 2025 ...',
#   'content': 'Celebrate Singapore National Day 2025 ...',
#   'source': 'Travelodge Hotels Asia (451KB)',
#   'resolution': '2083 x 1173',
#   'img_src': 'https://www.travelodgehotels.asia/wp-content/uploads/2025/07/SG60.webp',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0AeKrCkD76aUk-M5GhSxoHR-Wo5nmUWfxikgcf2gmnvXUpuI&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.travelodgehotels.asia',
#    '/best-ways-to-celebrate-singapore-national-day/',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [98],
#   'score': 0.01020408163265306,
#   'category': 'images'},
#  {'url': 'https://www.straitstimes.com/life/singapore-ranks-no-3-in-list-of-worlds-magnetic-cities',
#   'title': "Singapore ranks No. 3 in list of world's 'magnetic cities ...",
#   'content': 'magnetic cities ...',
#   'source': 'The Straits Times (215KB)',
#   'resolution': '1140 x 760',
#   'img_src': 'https://cassette.sphdigital.com.sg/image/straitstimes/cbf71e57bd5f524352872516d471df4c338db04f069cdeff095601b5fee289ed',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSiJS1DjDBHrn_9ykVUdeftyKOzPoTw_GKu4MALnIz6kUGNXgM&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https',
#    'www.straitstimes.com',
#    '/life/singapore-ranks-no-3-in-list-of-worlds-magnetic-cities',
#    '',
#    '',
#    ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [99],
#   'score': 0.010101010101010102,
#   'category': 'images'},
#  {'url': 'https://www.nhb.gov.sg/nationalmuseum/',
#   'title': 'National Museum of Singapore',
#   'content': '',
#   'source': 'www.nhb.gov.sg (196KB)',
#   'resolution': '800 x 800',
#   'img_src': 'https://www.nhb.gov.sg/nationalmuseum/-/media/nms2024/slides/homepage/nms-building-sm-logo.jpg',
#   'thumbnail_src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSqoN2pfIhkYIwftqxYbAMa6iMipWIn7jS3TLbVMVrBa2Hi22s&s',
#   'template': 'images.html',
#   'engine': 'google images',
#   'parsed_url': ['https', 'www.nhb.gov.sg', '/nationalmuseum/', '', '', ''],
#   'thumbnail': '',
#   'priority': '',
#   'engines': ['google images'],
#   'positions': [100],
#   'score': 0.01,
#   'category': 'images'}]
